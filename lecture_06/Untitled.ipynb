# %%
import cv2
import matplotlib.pyplot as plt

# %%
cap = cv2.VideoCapture(0)

# %%
tup = cap.read()

# %%
tup[1].shape
# Out:
# (720, 1280, 3)

# %%
plt.imshow(tup[1])

# %%
cap.release()

# %%
import numpy as np

# %%
arr = np.arange(10).reshape(5, 2)

# %%
arr.prod(axis=1).argmax()
# Out:
# 4

# %%
 old = np.zeros([0, 10000])

# %%
old.shape
# Out:
# (0, 10000)

# %%
np.full?
