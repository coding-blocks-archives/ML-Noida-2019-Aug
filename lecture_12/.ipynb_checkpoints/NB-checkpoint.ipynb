# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("mushrooms.csv")

# %%
df["type"].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
df.head()
# Out:
#   type cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0    p         x           s         n       t    p               f
# 1    e         x           s         y       t    a               f
# 2    e         b           s         w       t    l               f
# 3    p         x           y         w       t    p               f
# 4    e         x           s         g       f    n               f
#
#   gill_spacing gill_size gill_color   ...   stalk_surface_below_ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
#
#   stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring_number ring_type spore_print_color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
le = LabelEncoder()

# %%
out = df.apply(le.fit_transform)

# %%
le.classes_
# Out:
# array(['d', 'g', 'l', 'm', 'p', 'u', 'w'], dtype=object)

# %%
out.head()
# Out:
#    type  cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 0     1          5            2          4        1     6                1
# 1     0          5            2          9        1     0                1
# 2     0          0            2          8        1     3                1
# 3     1          5            3          8        1     6                1
# 4     0          5            2          3        0     5                1
#
#    gill_spacing  gill_size  gill_color   ...     stalk_surface_below_ring  \
# 0             0          1           4   ...                            2
# 1             0          0           4   ...                            2
# 2             0          0           5   ...                            2
# 3             0          1           5   ...                            2
# 4             1          0           4   ...                            2
#
#    stalk_color_above_ring  stalk_color_below_ring  veil_type  veil_color  \
# 0                       7                       7          0           2
# 1                       7                       7          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       7                       7          0           2
#
#    ring_number  ring_type  spore_print_color  population  habitat
# 0            1          4                  2           3        5
# 1            1          4                  3           2        1
# 2            1          4                  3           2        3
# 3            1          4                  2           3        5
# 4            1          0                  3           0        1
#
# [5 rows x 23 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
...     out.iloc[:, 1:], out.iloc[:, 0], test_size=0.33, random_state=42)

# %%
probs = {}

klasses, counts = np.unique(y_train, return_counts=True)

for klass, count in zip(klasses, counts):
    
    klass_data = {
        "prior" : count,
        "columns" : {}
    }
    
    klass_cut = X_train.loc[y_train == klass]
    
    for column in klass_cut.columns:
        vals, counts = np.unique(klass_cut[column], return_counts=True)
        val_dict = dict(zip(vals, counts))
        klass_data["columns"][column] = val_dict
    
    probs[klass] = klass_data

# %%
probs
# Out:
# {0: {'prior': 2830,
#   'columns': {'cap_shape': {0: 255, 2: 1078, 3: 163, 4: 22, 5: 1312},
#    'cap_surface': {0: 1055, 2: 772, 3: 1003},
#    'cap_color': {0: 38,
#     1: 24,
#     2: 415,
#     3: 688,
#     4: 854,
#     5: 42,
#     6: 10,
#     7: 11,
#     8: 494,
#     9: 254},
#    'bruises': {0: 968, 1: 1862},
#    'odor': {0: 264, 3: 253, 5: 2313},
#    'gill_attachment': {0: 132, 1: 2698},
#    'gill_spacing': {0: 2037, 1: 793},
#    'gill_size': {0: 2646, 1: 184},
#    'gill_color': {1: 69,
#     2: 158,
#     3: 141,
#     4: 221,
#     5: 653,
#     6: 42,
#     7: 535,
#     9: 302,
#     10: 668,
#     11: 41},
#    'stalk_shape': {0: 1069, 1: 1761},
#    'stalk_root': {0: 488, 1: 1309, 2: 336, 3: 576, 4: 121},
#    'stalk_surface_above_ring': {0: 280, 1: 87, 2: 2452, 3: 11},
#    'stalk_surface_below_ring': {0: 301, 1: 92, 2: 2305, 3: 132},
#    'stalk_color_above_ring': {2: 69, 3: 394, 4: 11, 5: 132, 6: 394, 7: 1830},
#    'stalk_color_below_ring': {2: 70, 3: 390, 4: 43, 5: 132, 6: 382, 7: 1813},
#    'veil_type': {0: 2830},
#    'veil_color': {0: 70, 1: 62, 2: 2698},
#    'ring_number': {1: 2474, 2: 356},
#    'ring_type': {0: 687, 1: 32, 4: 2111},
#    'spore_print_color': {0: 33,
#     1: 32,
#     2: 1083,
#     3: 1199,
#     4: 34,
#     6: 30,
#     7: 388,
#     8: 31},
#    'population': {0: 260, 1: 203, 2: 265, 3: 572, 4: 807, 5: 723},
#    'habitat': {0: 1284, 1: 927, 2: 164, 3: 170, 4: 86, 5: 60, 6: 139}}},
#  1: {'prior': 2613,
#   'columns': {'cap_shape': {0: 35, 1: 3, 2: 1024, 3: 420, 5: 1131},
#    'cap_surface': {0: 509, 1: 2, 2: 943, 3: 1159},
#    'cap_color': {0: 81, 1: 10, 2: 586, 3: 529, 4: 683, 5: 57, 8: 217, 9: 450},
#    'bruises': {0: 2208, 1: 405},
#    'odor': {1: 128, 2: 1446, 4: 26, 5: 77, 6: 162, 7: 391, 8: 383},
#    'gill_attachment': {0: 13, 1: 2600},
#    'gill_spacing': {0: 2537, 1: 76},
#    'gill_size': {0: 1126, 1: 1487},
#    'gill_color': {0: 1167,
#     2: 343,
#     3: 336,
#     4: 43,
#     5: 75,
#     7: 429,
#     8: 15,
#     9: 31,
#     10: 156,
#     11: 18},
#    'stalk_shape': {0: 1255, 1: 1358},
#    'stalk_root': {0: 1185, 1: 1233, 2: 33, 3: 162},
#    'stalk_surface_above_ring': {0: 89, 1: 1505, 2: 1012, 3: 7},
#    'stalk_surface_below_ring': {0: 99, 1: 1448, 2: 1015, 3: 51},
#    'stalk_color_above_ring': {0: 288, 1: 26, 4: 283, 6: 865, 7: 1144, 8: 7},
#    'stalk_color_below_ring': {0: 291, 1: 26, 4: 284, 6: 884, 7: 1112, 8: 16},
#    'veil_type': {0: 2613},
#    'veil_color': {2: 2606, 3: 7},
#    'ring_number': {0: 26, 1: 2540, 2: 47},
#    'ring_type': {0: 1192, 2: 862, 3: 26, 4: 533},
#    'spore_print_color': {1: 1053, 2: 146, 3: 144, 5: 47, 7: 1223},
#    'population': {1: 38, 3: 231, 4: 1903, 5: 441},
#    'habitat': {0: 832, 1: 499, 2: 417, 3: 24, 4: 669, 5: 172}}}}

# %%
class NB:
    
    def __init__(self):
        pass
    
    def fit(self, X_train, y_train):
        
        probs = {}

        klasses, counts = np.unique(y_train, return_counts=True)

        for klass, count in zip(klasses, counts):

            klass_data = {
                "prior" : count,
                "columns" : {}
            }

            klass_cut = X_train.loc[y_train == klass]

            for column in klass_cut.columns:
                vals, counts = np.unique(klass_cut[column], return_counts=True)
                val_dict = dict(zip(vals, counts))
                klass_data["columns"][column] = val_dict

            probs[klass] = klass_data
        
            
        self.probs = probs
        
        
    def predict(self, X):
        result = []
        for _, row in X.iterrows():
            result.append(self.predict_point(row))
            
        return result
    
    def predict_point(self, row):
        
        results = []
        
        for klass in self.probs:
            klass_d = self.probs[klass]
            total = klass_d["prior"]
            
            for column in klass_d["columns"]:
                
                pro = klass_d["columns"][column]
                if row[column] in pro:
                    total *= pro[row[column]]
                else:
                    total *= 0
            
            results.append((total, klass))
            
        return sorted(results, reverse=True)[0][1]

# %%
model = NB()

# %%
model.fit(X_train, y_train)

# %%
model.predict(X_test.iloc[:10])
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:51: RuntimeWarning: overflow encountered in longlong_scalars
# [1, 1, 0, 0, 1, 1, 1, 1, 0, 0]

# %%
y_test[:10]
# Out:
# 1971    0
# 6654    1
# 5606    1
# 3332    0
# 6988    1
# 5761    1
# 5798    1
# 3064    1
# 1811    0
# 3422    0
# Name: type, dtype: int32
