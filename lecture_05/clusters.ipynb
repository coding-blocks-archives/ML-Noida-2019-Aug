# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mean1 = [4, 4]
covar1 = [[1, -1], [-1, 5]]

mean2 = [-1, -1]
covar2 = [[1, 0], [0, 1]]

# %%
d1 = np.random.multivariate_normal(mean1, covar1, 1000)
d2 = np.random.multivariate_normal(mean2, covar2, 1000)

# %%
d1.shape
# Out:
# (1000, 2)

# %%
plt.scatter(d1[:, 0], d1[:, 1])

# %%
d1[:, 0].shape
# Out:
# (1000,)

# %%
plt.figure()
plt.scatter(d1[:, 0], d1[:, 1], label="cluster-1")
plt.scatter(d2[:, 0], d2[:, 1], label="cluster-2")
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.xlabel("longitude")
plt.ylabel("latitube")
plt.title("Poore 20 number")
plt.legend()
plt.show()

# %%
np.var(d1[:, 0])
# Out:
# 0.9980574268978525

# %%
d1.shape
# Out:
# (1000, 2)

# %%
d2.shape
# Out:
# (1000, 2)

# %%
X = np.vstack([d1, d2])

y = np.ones([len(d1) + len(d2)], dtype=int)
y[len(d2):] = 2

# %%
y
# Out:
# array([1, 1, 1, ..., 2, 2, 2])

# %%
plt.figure()
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.show()

# %%
! python3 -m pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/site-packages (0.20.2)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python3.7/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.7/site-packages (from scikit-learn) (1.16.1)

# %%
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(n_samples=1000, centers=2, random_state=42)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)
